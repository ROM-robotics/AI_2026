# %%
import cv2 as cv

img = cv.imread('lena_color_256.tif',-1)
cv.imshow('Lina',img)
cv.waitKey(0)
cv.destroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 import cv2 as cv
#       3 img = cv.imread('lena_color_256.tif',-1)
#       4 cv.imshow('Lina',img)
#
# ImportError: /home/mr_robot/anaconda3/envs/myenv/lib/python3.11/lib-dynload/../../libssl.so.3: version `OPENSSL_3.2.0' not found (required by /home/mr_robot/anaconda3/envs/myenv/lib/python3.11/site-packages/../../././libcurl.so.4)

# %%
import cv2 as cv

img = cv.imread('lena_color_512.tif')
cv.imshow('Lina',img)
cv.imwrite("blabla.jpg",img)
cv.waitKey(0)
cv.destroyAllWindows()
