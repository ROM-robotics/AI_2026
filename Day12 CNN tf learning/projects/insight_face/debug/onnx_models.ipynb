# %%
import netron
netron.start(r"C:\Users\RAIDER\Desktop\ai\vision.ai\developments\insight_face\automated_scripts\models\models\buffalo_l\1k3d68.onnx")
# Out:
# Serving 'C:\Users\RAIDER\Desktop\ai\vision.ai\developments\insight_face\automated_scripts\models\models\buffalo_l\1k3d68.onnx' at http://localhost:8080
# ('localhost', 8080)

# %%
import netron
netron.start(r"C:\Users\RAIDER\Desktop\ai\vision.ai\developments\insight_face\automated_scripts\models\models\buffalo_l\w600k_r50.onnx")
# Out:
# Serving 'C:\Users\RAIDER\Desktop\ai\vision.ai\developments\insight_face\automated_scripts\models\models\buffalo_l\w600k_r50.onnx' at http://localhost:8080
# ('localhost', 8080)

# %%
import netron
netron.start(r"C:\Users\RAIDER\Desktop\ai\vision.ai\developments\insight_face\automated_scripts\models\models\buffalo_l\genderage.onnx")
# Out:
# Serving 'C:\Users\RAIDER\Desktop\ai\vision.ai\developments\insight_face\automated_scripts\models\models\buffalo_l\genderage.onnx' at http://localhost:8080
# ('localhost', 8080)
